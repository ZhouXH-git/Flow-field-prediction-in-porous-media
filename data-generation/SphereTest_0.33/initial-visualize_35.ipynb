# %%
import numpy as np
import matplotlib.pylab as plt

# %%
ID = np.fromfile('pack_N512_33',dtype = np.uint8)
Nz = 512; Ny = 512; Nx = 512
ID = ID.reshape(Nz,Ny,Nx)

# %%
ID.shape
# Out:
# (512, 512, 512)

# %%
IDsub = ID[0:80,0:80,0:80]
IDsub.shape
# Out:
# (80, 80, 80)

# %%
IDsub[0,0,0]
# Out:
# 0

# %%
plt.figure(1)
plt.title('segmented image')
plt.pcolormesh(ID[256,:,:],cmap='hot')
plt.grid(True)
plt.axis('equal')
plt.show()
